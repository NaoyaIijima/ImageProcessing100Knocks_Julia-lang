# %%
using Images, ImageView, FileIO

# %%
img = load("./../assets/imori.jpg")
# Out:
# 128×128 Array{RGB4{N0f8},2} with eltype RGB4{Normed{UInt8,8}}:
#  RGB4{N0f8}(0.263,0.314,0.518)  …  RGB4{N0f8}(0.392,0.49,0.639)
#  RGB4{N0f8}(0.275,0.341,0.545)     RGB4{N0f8}(0.357,0.431,0.596)
#  RGB4{N0f8}(0.271,0.333,0.537)     RGB4{N0f8}(0.322,0.408,0.631)
#  RGB4{N0f8}(0.271,0.314,0.522)     RGB4{N0f8}(0.251,0.361,0.639)
#  RGB4{N0f8}(0.282,0.349,0.529)     RGB4{N0f8}(0.212,0.29,0.537)
#  RGB4{N0f8}(0.263,0.369,0.537)  …  RGB4{N0f8}(0.329,0.357,0.529)
#  RGB4{N0f8}(0.259,0.361,0.553)     RGB4{N0f8}(0.278,0.349,0.506)
#  RGB4{N0f8}(0.302,0.361,0.584)     RGB4{N0f8}(0.278,0.435,0.635)
#  RGB4{N0f8}(0.306,0.404,0.553)     RGB4{N0f8}(0.498,0.541,0.749)
#  RGB4{N0f8}(0.306,0.38,0.545)      RGB4{N0f8}(0.49,0.604,0.769)
#  RGB4{N0f8}(0.357,0.412,0.588)  …  RGB4{N0f8}(0.667,0.647,0.765)
#  RGB4{N0f8}(0.302,0.373,0.561)     RGB4{N0f8}(0.733,0.635,0.761)
#  RGB4{N0f8}(0.259,0.369,0.553)     RGB4{N0f8}(0.573,0.431,0.62)
#  ⋮                              ⋱
# ...

# %%
img[1:100, 1:100]
# Out:
# 100×100 Array{RGB4{N0f8},2} with eltype RGB4{Normed{UInt8,8}}:
#  RGB4{N0f8}(0.263,0.314,0.518)  …  RGB4{N0f8}(0.337,0.353,0.502)
#  RGB4{N0f8}(0.275,0.341,0.545)     RGB4{N0f8}(0.498,0.533,0.757)
#  RGB4{N0f8}(0.271,0.333,0.537)     RGB4{N0f8}(0.541,0.624,0.831)
#  RGB4{N0f8}(0.271,0.314,0.522)     RGB4{N0f8}(0.482,0.576,0.765)
#  RGB4{N0f8}(0.282,0.349,0.529)     RGB4{N0f8}(0.388,0.463,0.682)
#  RGB4{N0f8}(0.263,0.369,0.537)  …  RGB4{N0f8}(0.396,0.478,0.663)
#  RGB4{N0f8}(0.259,0.361,0.553)     RGB4{N0f8}(0.529,0.627,0.784)
#  RGB4{N0f8}(0.302,0.361,0.584)     RGB4{N0f8}(0.518,0.631,0.855)
#  RGB4{N0f8}(0.306,0.404,0.553)     RGB4{N0f8}(0.416,0.533,0.776)
#  RGB4{N0f8}(0.306,0.38,0.545)      RGB4{N0f8}(0.478,0.565,0.761)
#  RGB4{N0f8}(0.357,0.412,0.588)  …  RGB4{N0f8}(0.498,0.576,0.773)
#  RGB4{N0f8}(0.302,0.373,0.561)     RGB4{N0f8}(0.545,0.671,0.902)
#  RGB4{N0f8}(0.259,0.369,0.553)     RGB4{N0f8}(0.498,0.655,0.894)
#  ⋮                              ⋱
# ...

# %%
dump(img[1, 1])
# Out:
# RGB4{Normed{UInt8,8}}
#   r: Normed{UInt8,8}
#     i: UInt8 0x43
#   g: Normed{UInt8,8}
#     i: UInt8 0x50
#   b: Normed{UInt8,8}
#     i: UInt8 0x84
#   alphadummy: Normed{UInt8,8}
#     i: UInt8 0xff

# %%
c = img[1, 1];
